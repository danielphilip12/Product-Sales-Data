# %% [markdown]
# <a href="https://colab.research.google.com/github/danielphilip12/Product-Sales-Data/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd # import pandas library
df = pd.read_excel('/content/drive/MyDrive/Projects/Product Sales/data/Products_Sales_Data.xlsx') # import excel file as a dataframe
df.head() # display first 5 rows of data
# Out:
#   Product  Units sold  Price/unit ($) Month
# 0       B         249       10.721280   Jan
# 1       A         201       20.889330   Feb
# 2       C         221       74.286292   Mar
# 3       B         218       86.502598   Apr
# 4       B         237       36.364192   May
